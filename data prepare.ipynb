# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df_train = pd.read_csv(r'C:\Users\yoyo\Downloads\House price prediction\data\train.csv')

# %%
df_train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
#histogram
sns.distplot(df_train['SalePrice']);

# %%
#scatter plot grlivarea/saleprice
var = 'GrLivArea'
data = pd.concat([df_train['SalePrice'], df_train[var]], axis=1)
data.plot.scatter(x=var, y='SalePrice', ylim=(0,800000));

# %%
data.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-0af1fa900cec> in <module>
# ----> 1 data.type
#
# C:\Users\yoyo\Desktop\WPy64-3720\python-3.7.2.amd64\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
#scatter plot totalbsmtsf/saleprice
from sklearn.preprocessing import StandardScaler
var = 'TotalBsmtSF'
data = pd.concat([df_train['SalePrice'], df_train[var]], axis=1)
data_sc=StandardScaler().fit_transform(data)
plt.scatter(data_sc[:,1],data_sc[:,0])

# %%
data_sc.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-ac000b4dc965> in <module>
# ----> 1 data_sc.type
#
# AttributeError: 'numpy.ndarray' object has no attribute 'type'

# %%
df_train['TotalBsmtSF'].to_numpy()
# Out:
# array([ 856, 1262,  920, ..., 1152, 1078, 1256], dtype=int64)

# %%
#missing data
total = df_train.isnull().sum().sort_values(ascending=False)
percent = (df_train.isnull().sum()/df_train.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head()
# Out:
#              Total   Percent
# PoolQC        1453  0.995205
# MiscFeature   1406  0.963014
# Alley         1369  0.937671
# Fence         1179  0.807534
# FireplaceQu    690  0.472603

# %%
from sklearn.preprocessing import StandardScaler
#standardizing data
df_train_sc = StandardScaler().fit_transform(df_train);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-8f82890fe0bd> in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 #standardizing data
# ----> 3 df_train_sc = StandardScaler().fit_transform(df_train);
#
# C:\Users\yoyo\Desktop\WPy64-3720\python-3.7.2.amd64\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     462         if y is None:
#     463             # fit method of arity 1 (unsupervised transformation)
# --> 464             return self.fit(X, **fit_params).transform(X)
#     465         else:
#     466             # fit method of arity 2 (supervised transformation)
#
# C:\Users\yoyo\Desktop\WPy64-3720\python-3.7.2.amd64\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     643         # Reset internal state before fitting
#     644         self._reset()
# ...
